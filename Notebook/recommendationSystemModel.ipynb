# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
import pickle

# %%
# Load Myntra dataset
myntra = pd.read_csv('myntra_excel.csv')

# %%
myntra.shape
# Out:
# (15000, 26)

# %%
# Remove duplicate entries based on title from myntra
myntra  = myntra.drop_duplicates(subset=['title'])
myntra.shape
# Out:
# (11250, 26)

# %%
myntra
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      cc51c3dd925d9d84e2fb28c7918dbbc3  2019-08-11 05:49:46 +0000
# 1      c7e2fe388a93dae5c86b50dd8a5dbd7a  2019-07-03 01:04:34 +0000
# 2      76949d78057a633aace6246045eefd66  2019-07-15 09:43:31 +0000
# 3      5f83f6b51da1ef93bc0585577b6991e6  2019-07-15 14:11:14 +0000
# 4      890bf4355c319a4211296b9d3176d11f  2019-06-01 08:17:28 +0000
# ...                                 ...                        ...
# 14993  65cd8b64bac9149ae6376fc9f0291b85  2019-08-19 03:44:04 +0000
# 14994  fa6d9090467edc3dc0706e6c66707bd1  2019-08-19 07:01:59 +0000
# 14996  d42876ac4e79f4f8eafce06f42b83c4e  2019-08-19 15:55:34 +0000
# 14997  b0898407db4c65e025d0e9de6ac6732e  2019-08-14 05:37:01 +0000
# 14998  ec0aa336bb97ba406b7951bcc2aabdfc  2019-08-17 01:51:31 +0000
#
#        product_id                                               link     size  \
# 0         6937673  https://www.myntra.com/tops/imara/imara-women-...       XL
# 1         7441182  https://www.myntra.com/kurtas/house-of-pataudi...       XL
# 2         9245141  https://www.myntra.com/pillows/the-white-willo...        S
# 3         1314889  https://www.myntra.com/dupatta/dupatta-bazaar/...  Onesize
# 4         7705322  https://www.myntra.com/kurta-sets/manyavar/man...        S
# ...           ...                                                ...      ...
# 14993     2366741                     https://www.myntra.com/2366741        M
# 14994     6554346                     https://www.myntra.com/6554346       XL
# 14996     5504617  https://www.myntra.com/kurtas/shakumbhari/shak...      XXL
# 14997     4375262                     https://www.myntra.com/4375262        M
# 14998     2012151                     https://www.myntra.com/2012151        M
#
#            variant_sku             brand  \
# 0           6937673_XL             IMARA
# 1           7441182_XL  House of Pataudi
# 2            9245141_S  The White Willow
# 3      1314889_Onesize    Dupatta Bazaar
# 4            7705322_S          Manyavar
# ...                ...               ...
# 14993        2366741_M             Shree
# 14994       6554346_XL          Freehand
# 14996      5504617_XXL       Shakumbhari
# 14997        4375262_M             Anouk
# 14998        2012151_M             Anouk
#
#                                        care_instructions dominant_material  \
# 0                                  Polyester | Dry-clean         Polyester
# 1                                100% cottonMachine-wash            cotton
# 2      Polycotton | Only spot clean by hand with warm...            Cotton
# 3                                    Chiffon | Hand-wash           Chiffon
# 4      Top fabric: Silk Blend | Bottom fabric: Silk B...              Silk
# ...                                                  ...               ...
# 14993                                 100% LivaHand-wash              Liva
# 14994  Top fabric: Pure Cotton | Bottom fabric: Pure ...            Cotton
# 14996                            Cotton  |  Machine-wash            Cotton
# 14997                        100% acrylic | Machine-wash           acrylic
# 14998                         Polyester  |  Machine-wash         Polyester
#
#                                                    title  ...  \
# 0                            IMARA Women Black Solid Top  ...
# 1      House of Pataudi Men Black Printed Straight Kurta  ...
# 2      The White Willow Unisex Off-White Therapedic M...  ...
# 3                            Dupatta Bazaar Pink Dupatta  ...
# 4      Manyavar Men Yellow & White Self Design Kurta ...  ...
# ...                                                  ...  ...
# 14993     Shree Women Grey & Red Floral Print Maxi Dress  ...
# 14994  Freehand Men Red & White Self-Design Kurta wit...  ...
# 14996    Shakumbhari Women Pink Embroidered A-Line Kurta  ...
# 14997     Anouk Women Green Floral Foil Printed Cardigan  ...
# 14998   Anouk Women Green & White Printed Straight Kurta  ...
#
#                                                 size_fit  \
# 0            The model (height 5'8") is wearing a size S
# 1              The model (height 6') is wearing a size M
# 2            Dimensions: 58.42 cm x 33.02 cm x 10.16 cm
# 3                   Length: 2.3 metres Width: 1.1 metres
# 4              The model (height 6') is wearing a size M
# ...                                                  ...
# 14993  Semi-Fit  The model (height 5'8") is wearing a...
# 14994          The model (height 6') is wearing a size M
# 14996        The model (height 5'8") is wearing a size S
# 14997        The model (height 5'8") is wearing a size S
# 14998        The model (height 5'8") is wearing a size S
#
#                                        complete_the_look  \
# 0      Improve your personal style with a brand new t...
# 1      From House of Pataudi, this kurta is a great w...
# 2      The White Willow has been founded with the vis...
# 3      Complement your ethnic ensemble with this dupa...
# 4      From Manyavar, this kurta is a great way to sh...
# ...                                                  ...
# 14993  This timeless and sumptuous Shree dress is sui...
# 14994  This in-style kurta from Freehand is a must-ha...
# 14996  Make a statement with this elegant kurta from ...
# 14997  Embrace your casual side with this in-season s...
# 14998  Show off your elegant style with a brand new k...
#
#                                                     type variant_price  \
# 0                Clothing/Women/Tops/IMARA/More by IMARA           959
# 1      Clothing/Men/Kurtas/House of Pataudi/More by H...           799
# 2      Home/Unisex/Pillows/The White Willow/More by T...          1399
# 3      Clothing/Women/Dupatta/Dupatta Bazaar/More by ...           349
# 4      Clothing/Men/Kurta Sets/Manyavar/More by Manyavar          2999
# ...                                                  ...           ...
# 14993         Clothing/Women/Dresses/Shree/More by Shree           764
# 14994  Clothing/Men/Kurta Sets/Freehand/More by Freehand           919
# 14996  Clothing/Women/Kurtas/Shakumbhari/More by Shak...           627
# 14997        Clothing/Women/Sweaters/Anouk/More by Anouk           759
# 14998          Clothing/Women/Kurtas/Anouk/More by Anouk           599
#
#       variant_compare_at_price ideal_for   is_in_stock  \
# 0                         1599     Women  Out of Stock
# 1                         1999       Men      In Stock
# 2                         2799    Unisex      In Stock
# 3                          499     Women      In Stock
# 4                         2999       Men  Out of Stock
# ...                        ...       ...           ...
# 14993                     1699     Women  Out of Stock
# 14994                     2299       Men  Out of Stock
# 14996                     1395     Women  Out of Stock
# 14997                     1899     Women  Out of Stock
# 14998                     1499     Women  Out of Stock
#
#                                                inventory  \
# 0                                                      0
# 1      Shape : Straight | Sleeve Styling : Regular Sl...
# 2      Number of Components : 1 | Material : Polycott...
# 3      Pattern : Solid | Occasion : Daily | Border : ...
# 4      Occasion : Festive | Number of Components : 2 ...
# ...                                                  ...
# 14993                                                  0
# 14994                                                  0
# 14996                                                  0
# 14997                                                  0
# 14998                                                  0
#
#                                           specifications  \
# 0      Transparency : Opaque | Sleeve Styling : Bell ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14993  Knit or Woven : Woven | Transparency : Opaque ...
# 14994  Occasion : Daily | Number of Components : 2 | ...
# 14996  Shape : A-Line | Business Unit : Apparel | Sle...
# 14997  Closure : Button | Occasion : Casual | Print o...
# 14998  Shape : Straight | Sleeve Styling : Regular Sl...
#
#                               Unnamed: 25
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 14993                                 NaN
# 14994                                 NaN
# 14996  https://www.myntra.com/shakumbhari
# 14997                                 NaN
# 14998                                 NaN
#
# [11250 rows x 26 columns]

# %%
# After removing duplicate values, Reset index of database
myntra.reset_index(drop=True, inplace = True)

# %%
# All the features of the dataset
features = myntra.columns
print(features)
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_id', 'link', 'size',
#        'variant_sku', 'brand', 'care_instructions', 'dominant_material',
#        'title', 'actual_color', 'dominant_color', 'product_type', 'images',
#        'body', 'product_details', 'size_fit', 'complete_the_look', 'type',
#        'variant_price', 'variant_compare_at_price', 'ideal_for', 'is_in_stock',
#        'inventory', 'specifications', 'Unnamed: 25'],
#       dtype='object')

# %%
# To check if the dataset has any null values or not
myntra.isnull().sum()
# Out:
# uniq_id                         0
# crawl_timestamp                 0
# product_id                      0
# link                            0
# size                            0
# variant_sku                     0
# brand                           0
# care_instructions              20
# dominant_material             431
# title                           0
# actual_color                  784
# dominant_color                790
# product_type                 1200
# images                          0
# body                            0
# product_details                 0
# size_fit                     1007
# complete_the_look             176
# type                            0
# variant_price                   0
# variant_compare_at_price        0
# ideal_for                       0
# is_in_stock                     0
# inventory                      93
# specifications               4327
# Unnamed: 25                 10812
# dtype: int64

# %%
# First row
myntra.loc[0]
# Out:
# uniq_id                                      cc51c3dd925d9d84e2fb28c7918dbbc3
# crawl_timestamp                                     2019-08-11 05:49:46 +0000
# product_id                                                            6937673
# link                        https://www.myntra.com/tops/imara/imara-women-...
# size                                                                       XL
# variant_sku                                                        6937673_XL
# brand                                                                   IMARA
# care_instructions                                       Polyester | Dry-clean
# dominant_material                                                   Polyester
# title                                             IMARA Women Black Solid Top
# actual_color                                                            Black
# dominant_color                                                          Black
# product_type                                                              Top
# images                      http://assets.myntassets.com/v1/assets/images/...
# body                        Black solid woven regular top,has a V-neck, th...
# product_details             Black solid woven regular top,has a V-neck, th...
# size_fit                          The model (height 5'8") is wearing a size S
# complete_the_look           Improve your personal style with a brand new t...
# type                                  Clothing/Women/Tops/IMARA/More by IMARA
# variant_price                                                             959
# variant_compare_at_price                                                 1599
# ideal_for                                                               Women
# is_in_stock                                                      Out of Stock
# inventory                                                                   0
# specifications              Transparency : Opaque | Sleeve Styling : Bell ...
# Unnamed: 25                                                               NaN
# Name: 0, dtype: object

# %%
myntra['product_id'].value_counts()
# Out:
# 9539307    2
# 9196975    2
# 9792639    2
# 6420023    1
# 9872041    1
#           ..
# 5125468    1
# 7798109    1
# 7726430    1
# 9366879    1
# 8914943    1
# Name: product_id, Length: 11247, dtype: int64

# %%
# Drop duplicate products based on product_id
myntra = myntra.drop_duplicates(subset = ["product_id"])
myntra.shape
# Out:
# (11247, 26)

# %%
# No duplicate entries available based on product_id
myntra['product_id'].value_counts()
# Out:
# 6420023    1
# 1471155    1
# 1129130    1
# 8073899    1
# 7097004    1
#           ..
# 7570778    1
# 5125468    1
# 7798109    1
# 7726430    1
# 8914943    1
# Name: product_id, Length: 11247, dtype: int64

# %%
myntra['ideal_for'].value_counts()
# Out:
# Women     7000
# Men       2741
# Unisex     546
# Girls      534
# Boys       426
# Name: ideal_for, dtype: int64

# %%
sns.countplot(x = 'ideal_for', data = myntra)
# Out:
# <AxesSubplot:xlabel='ideal_for', ylabel='count'>

# %%
myntra['brand'].value_counts()
# Out:
# Anouk                    1158
# Biba                      832
# Libas                     607
# Shree                     560
# Global Desi               523
#                          ...
# IMYOUNG                     1
# HIGHLANDER                  1
# Boutique Living India       1
# John Pride                  1
# Kurti's by Menka            1
# Name: brand, Length: 364, dtype: int64

# %%
# Top 10 brands bard plot
plt.figure(figsize=(10,6))
sns.barplot(x = myntra['brand'].value_counts().index[0:10] , y = myntra['brand'].value_counts().values[0:10] )
# Out:
# <AxesSubplot:>

# %%
Top_Brands = dict(myntra['brand'].value_counts()[0: 20])
print(Top_Brands)
# Out:
# {'Anouk': 1158, 'Biba': 832, 'Libas': 607, 'Shree': 560, 'Global Desi': 523, 'Fabindia': 312, 'IMARA': 288, 'Sangria': 272, 'GERUA': 214, 'DEYANN': 202, 'AKS': 200, 'SOJANYA': 182, 'Rangriti': 180, 'Inddus': 176, 'INDYA': 174, 'VASTRAMAY': 154, 'KISAH': 154, 'even': 140, 'Freehand': 128, 'Aj DEZInES': 128}

# %%
myntra['inventory'][0]
# Out:
# '0'

# %%
myntra['inventory'][1]
# Out:
# 'Shape : Straight | Sleeve Styling : Regular Sleeves | Occasion : Daily | Print or Pattern Type : Geometric | Number of Components : 1 | Design Styling : Regular | Colour Family : Monochrome | Neck : Mandarin Collar | Pattern : Printed | Body or Garment Size : Garment Measurements in | Sleeve Length : Long Sleeves | Weave Pattern : Regular | Fabric Purity : Pure | Stitch : Ready to Wear | Hemline : Straight | Wash Care : Machine Wash | Weave Type : Machine Weave | Length : Knee Length | Slit Detail : Side Slits | Fabric : Cotton'

# %%
# Firstly Fill every null values with ""
myntra['inventory'].fillna("", inplace = True)

# If string has length less than 2 = replace it with " " in inventory
def updateInventory(x):
    if(len(x) < 2):
        x = " "
    return x
myntra['inventory'] = myntra['inventory'].apply(updateInventory)


myntra['inventory']
# Out:
# c:\python3.9\lib\site-packages\pandas\core\series.py:4460: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# <ipython-input-20-4d5dfb9fb24e>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   myntra['inventory'] = myntra['inventory'].apply(updateInventory)
# 0
# 1        Shape : Straight | Sleeve Styling : Regular Sl...
# 2        Number of Components : 1 | Material : Polycott...
# 3        Pattern : Solid | Occasion : Daily | Border : ...
# 4        Occasion : Festive | Number of Components : 2 ...
#                                ...
# 11245
# 11246
# 11247
# 11248
# 11249
# Name: inventory, Length: 11247, dtype: object

# %%
# Split the string and then replace all numvers and regular expressions with " " and return preprocessed string which can bes used in model training
def preprocessInventory(x):

    ls = x.split(" | ")

    str = " ".join(ls)
    cleanString = re.sub('\W+',' ', str ).strip()
 
    return cleanString.lower()


myntra['Pre_Inventory'] = myntra['inventory'].apply(preprocessInventory)

myntra['Pre_Inventory']
# Out:
# <ipython-input-21-1f97981ab81a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   myntra['Pre_Inventory'] = myntra['inventory'].apply(preprocessInventory)
# 0
# 1        shape straight sleeve styling regular sleeves ...
# 2        number of components 1 material polycotton set...
# 3                pattern solid occasion daily border solid
# 4        occasion festive number of components 2 top pa...
#                                ...
# 11245
# 11246
# 11247
# 11248
# 11249
# Name: Pre_Inventory, Length: 11247, dtype: object

# %%
myntra['type'][0]
# Out:
# 'Clothing/Women/Tops/IMARA/More by IMARA'

# %%
# for getting all values separated by "/" and use it into model
def preprocessType(x):
    ls = x.split("/")
    str = ' '.join(ls).strip()
    return str.lower()


myntra['type'] = myntra['type'].apply(preprocessType)
# Out:
# <ipython-input-23-3747713cadab>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   myntra['type'] = myntra['type'].apply(preprocessType)

# %%
myntra['type'][0: 5]
# Out:
# 0              clothing women tops imara more by imara
# 1    clothing men kurtas house of pataudi more by h...
# 2    home unisex pillows the white willow more by t...
# 3    clothing women dupatta dupatta bazaar more by ...
# 4    clothing men kurta sets manyavar more by manyavar
# Name: type, dtype: object

# %%
myntra['body'][1]
# Out:
# "Black printed straight kurta, has a mandarin collar, long sleeves, straight hem, side slits and two pockets\nThe model (height 6') is wearing a size M\nFrom House of Pataudi, this kurta is a great way to show off your style.  Dress this black piece up with your favourite accessories and head out to any family event in style.\n100% cottonMachine-wash"

# %%
# Remove numbers and regular expressions from the string and preprocess it

def preproceBody(X):
    
    
    cleanString = re.sub(r"[^A-Za-z]+",' ', X )
    
    return cleanString.lower()

myntra['preprocess_body'] = myntra['body'].apply(preproceBody)
myntra['preprocess_body'][0]
# Out:
# <ipython-input-26-f9538af298e6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   myntra['preprocess_body'] = myntra['body'].apply(preproceBody)
# 'black solid woven regular top has a v neck three quarter sleeves an attached lining the model height is wearing a size s improve your personal style with a brand new three quarter sleeve top designed by imara when you want to have the perfect outfit for a fun lunch with the girls you ll want to put this black piece with an ankle boot and tapered leg pants polyester dry clean'

# %%
# Fill evenry null values with ""
myntra['care_instructions'].fillna("", inplace=True )
myntra['care_instructions'].isnull().sum()
# Out:
# 0

# %%
myntra['dominant_material'].fillna('', inplace = True)
myntra['dominant_color'].fillna("", inplace=True)
myntra['actual_color'].fillna("", inplace=True)
print(myntra['dominant_material'].isnull().sum())
print(myntra['dominant_color'].isnull().sum())
print(myntra['actual_color'].isnull().sum())
# Out:
# 0
# 0
# 0

# %%
# Multiple images are there so covert them into list
def image_process(x):
    x = x.split(" | ")

    return x

# %%
myntra['images'] = myntra['images'].apply(image_process)
myntra['images']
# Out:
# <ipython-input-30-68363c863d2c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   myntra['images'] = myntra['images'].apply(image_process)
# 0        [http://assets.myntassets.com/v1/assets/images...
# 1        [http://assets.myntassets.com/v1/assets/images...
# 2        [http://assets.myntassets.com/v1/assets/images...
# 3        [http://assets.myntassets.com/v1/assets/images...
# 4        [http://assets.myntassets.com/v1/assets/images...
#                                ...
# 11245    [http://assets.myntassets.com/v1/assets/images...
# 11246    [http://assets.myntassets.com/v1/assets/images...
# 11247    [http://assets.myntassets.com/v1/assets/images...
# 11248    [http://assets.myntassets.com/v1/assets/images...
# 11249    [http://assets.myntassets.com/v1/assets/images...
# Name: images, Length: 11247, dtype: object

# %%
# remove all data with less than 4 images
myntra = myntra[myntra['images'].apply(lambda x : len(x) > 3)]

# %%
myntra['specifications'].fillna("" , inplace = True)

# %%
# Preprocessing 
def preprocessCareInstruction(x):
    x = x.replace(u'\xa0', u' ')
    x = x.replace('-', '')
    
    
    ls = x.split(" | ")

    str = " ".join(ls)
    cleanString = re.sub('\W+',' ', str ).strip()

    return cleanString.lower()


myntra['care_instructions'] = myntra['care_instructions'].apply(preprocessCareInstruction)

myntra['care_instructions'][12]
# Out:
# 'top fabric tussar silk bottom fabric tussar silk handwash'

# %%
myntra.head()
# Out:
#                             uniq_id            crawl_timestamp  product_id  \
# 0  cc51c3dd925d9d84e2fb28c7918dbbc3  2019-08-11 05:49:46 +0000     6937673
# 1  c7e2fe388a93dae5c86b50dd8a5dbd7a  2019-07-03 01:04:34 +0000     7441182
# 2  76949d78057a633aace6246045eefd66  2019-07-15 09:43:31 +0000     9245141
# 5  6cb35dc135630e138f618b455014bf27  2019-07-28 13:03:52 +0000     2160958
# 6  07cc95890eb0034fda8c7160a3a5be6d  2019-06-17 05:21:59 +0000     7766518
#
#                                                 link size variant_sku  \
# 0  https://www.myntra.com/tops/imara/imara-women-...   XL  6937673_XL
# 1  https://www.myntra.com/kurtas/house-of-pataudi...   XL  7441182_XL
# 2  https://www.myntra.com/pillows/the-white-willo...    S   9245141_S
# 5  https://www.myntra.com/kurta-sets/wintage/wint...    L   2160958_L
# 6  https://www.myntra.com/skirts/geroo-jaipur/ger...   34  7766518_34
#
#               brand                                  care_instructions  \
# 0             IMARA                                 polyester dryclean
# 1  House of Pataudi                              100 cottonmachinewash
# 2  The White Willow  polycotton only spot clean by hand with warm w...
# 5           Wintage  kurta fabric linen bottom fabric pure cotton d...
# 6      Geroo Jaipur          first wash dry clean than after hand wash
#
#   dominant_material                                              title  ...  \
# 0         Polyester                        IMARA Women Black Solid Top  ...
# 1            cotton  House of Pataudi Men Black Printed Straight Kurta  ...
# 2            Cotton  The White Willow Unisex Off-White Therapedic M...  ...
# 5             Linen         Wintage Men Beige Solid Kurta with Pyjamas  ...
# 6                      Geroo Women Green cotton hand block print skirt  ...
#
#                                                 type variant_price  \
# 0            clothing women tops imara more by imara           959
# 1  clothing men kurtas house of pataudi more by h...           799
# 2  home unisex pillows the white willow more by t...          1399
# 5    clothing men kurta sets wintage more by wintage           979
# 6  clothing women skirts geroo jaipur more by ger...          1572
#
#   variant_compare_at_price ideal_for   is_in_stock  \
# 0                     1599     Women  Out of Stock
# 1                     1999       Men      In Stock
# 2                     2799    Unisex      In Stock
# 5                     1399       Men  Out of Stock
# 6                     1850     Women  Out of Stock
#
#                                            inventory  \
# 0
# 1  Shape : Straight | Sleeve Styling : Regular Sl...
# 2  Number of Components : 1 | Material : Polycott...
# 5
# 6  Knit or Woven : Knitted and Woven | Transparen...
#
#                                       specifications Unnamed: 25  \
# 0  Transparency : Opaque | Sleeve Styling : Bell ...         NaN
# 1                                                            NaN
# 2                                                            NaN
# 5  Sleeve Styling : Regular Sleeves | Occasion : ...         NaN
# 6                                                            NaN
#
#                                        Pre_Inventory  \
# 0
# 1  shape straight sleeve styling regular sleeves ...
# 2  number of components 1 material polycotton set...
# 5
# 6  knit or woven knitted and woven transparency o...
#
#                                      preprocess_body
# 0  black solid woven regular top has a v neck thr...
# 1  black printed straight kurta has a mandarin co...
# 2  set content pillow colour off white filling me...
# 5  beige solid kurta with pyjamas beige straight ...
# 6  green coloured free size dabu print cotton ski...
#
# [5 rows x 28 columns]

# %%
# reset index
myntra.reset_index(drop = True, inplace = True)

# %%
# Creating corpus of data for model training

myntra['corpusData'] = myntra['size']+ " "  + myntra['care_instructions']+ " " + myntra['dominant_material']+ " " + myntra['actual_color'] + " " + myntra['dominant_color'] + " " + myntra['product_type']+ " " + myntra['preprocess_body'] + " " + myntra['type'] + " " + myntra['ideal_for'] + " " + myntra['Pre_Inventory']

# %%
# Drop Unnecessery column
myntra.drop('Unnamed: 25', axis =1, inplace = True)

# %%
# Remove all null values
myntra.dropna(inplace = True)

# %%
myntra.shape
# Out:
# (8771, 28)

# %%
myntra.reset_index(inplace = True)

# %%
# Product_id == index
myntra['product_id'] = myntra['index']

# %%
myntra = myntra.drop_duplicates(subset=['title'])
myntra.shape
# Out:
# (8771, 29)

# %%
myntra['img1'] = myntra['images'].iloc[1][0]
myntra['img3'] = myntra['images'].iloc[1][0]
myntra['img2'] = myntra['images'].iloc[1][0]
myntra['img4'] = myntra['images'].iloc[1][0]

# %%
# Create 4 columns and add product images into it

for i in range(myntra.shape[0]):
    myntra['img1'].iloc[i] = myntra['images'].iloc[i][0]
    myntra['img2'].iloc[i] = myntra['images'].iloc[i][1]
    myntra['img3'].iloc[i] = myntra['images'].iloc[i][2]
    myntra['img4'].iloc[i] = myntra['images'].iloc[i][3]
# Out:
# c:\python3.9\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
myntra.shape
# Out:
# (8771, 33)

# %%
myntra.columns
# Out:
# Index(['index', 'uniq_id', 'crawl_timestamp', 'product_id', 'link', 'size',
#        'variant_sku', 'brand', 'care_instructions', 'dominant_material',
#        'title', 'actual_color', 'dominant_color', 'product_type', 'images',
#        'body', 'product_details', 'size_fit', 'complete_the_look', 'type',
#        'variant_price', 'variant_compare_at_price', 'ideal_for', 'is_in_stock',
#        'inventory', 'specifications', 'Pre_Inventory', 'preprocess_body',
#        'corpusData', 'img1', 'img3', 'img2', 'img4'],
#       dtype='object')

# %%
# Load ratings dataset
ratings = pd.read_csv('ratings.csv')

# %%
ratings.shape
# Out:
# (2419078, 4)

# %%
ratings.head()
# Out:
#    Unnamed: 0  userId  product_id  Rating
# 0           0    3269           0    4.30
# 1           1    4575           0    3.95
# 2           2    3844           0    3.72
# 3           3    1260           0    3.98
# 4           4    5298           0    4.37

# %%
# Drop unnecessery column
ratings.drop('Unnamed: 0' , axis =1 , inplace = True)

# %%
ratings.head(1)
# Out:
#    userId  product_id  Rating
# 0    3269           0     4.3

# %%
# merge ratings dataset with myntra using product_id
myntra_merge_ratings = ratings.merge(myntra , on="product_id")
myntra_merge_ratings.head(2)
# Out:
#    userId  product_id  Rating  index                           uniq_id  \
# 0    3269           0    4.30      0  cc51c3dd925d9d84e2fb28c7918dbbc3
# 1    4575           0    3.95      0  cc51c3dd925d9d84e2fb28c7918dbbc3
#
#              crawl_timestamp  \
# 0  2019-08-11 05:49:46 +0000
# 1  2019-08-11 05:49:46 +0000
#
#                                                 link size variant_sku  brand  \
# 0  https://www.myntra.com/tops/imara/imara-women-...   XL  6937673_XL  IMARA
# 1  https://www.myntra.com/tops/imara/imara-women-...   XL  6937673_XL  IMARA
#
#    ...   is_in_stock inventory  \
# 0  ...  Out of Stock
# 1  ...  Out of Stock
#
#                                       specifications Pre_Inventory  \
# 0  Transparency : Opaque | Sleeve Styling : Bell ...
# 1  Transparency : Opaque | Sleeve Styling : Bell ...
#
#                                      preprocess_body  \
# 0  black solid woven regular top has a v neck thr...
# 1  black solid woven regular top has a v neck thr...
#
#                                           corpusData  \
# 0  XL polyester dryclean Polyester Black Black To...
# 1  XL polyester dryclean Polyester Black Black To...
#
#                                                 img1  \
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img3  \
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img2  \
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img4
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
#
# [2 rows x 35 columns]

# %%
myntra_merge_ratings.shape
# Out:
# (2050568, 35)

# %%
# Total Number of counts on each products
ratingCount = (myntra_merge_ratings.groupby(by=['title'])['Rating'].count().reset_index().rename(columns = {'Rating': "TotalCountRating"})[["title", "TotalCountRating"]])

# %%
ratingCount
# Out:
#                                                   title  TotalCountRating
# 0            Global Desi Women Red & Pink Printed Tunic               275
# 1      Jaipur Kurti Women Blue Printed Maxi Flared S...               299
# 2       20Dresses Women Black & Blue Printed Maxi Dress               301
# 3                      9rasa Black Block Print Palazzos               279
# 4     A.T.U.N All Things Uber Nice Girls Mustard Yel...               305
# ...                                                 ...               ...
# 7427  studio rasa Women Navy-Blue & Green Flared Max...               257
# 7428  studio rasa Yellow & Off-White Handblock Print...               290
# 7429        trueBrowns Women Navy Blue Solid Maxi Dress               266
# 7430   trueBrowns Women Peach-Coloured Solid Maxi Dress               310
# 7431             trueBrowns Women Pink Solid Maxi Dress               261
#
# [7432 rows x 2 columns]

# %%
ratingCount.describe()
# Out:
#        TotalCountRating
# count       7432.000000
# mean         275.910657
# std           16.688340
# min          212.000000
# 25%          265.000000
# 50%          276.000000
# 75%          287.000000
# max          341.000000

# %%
# Average product rating on each product
averageRating = (myntra_merge_ratings.groupby(by=['title'])['Rating'].mean().reset_index().rename(columns = {'Rating': "AverageRatingCount"})[["title", "AverageRatingCount"]])

# %%
averageRating
# Out:
#                                                   title  AverageRatingCount
# 0            Global Desi Women Red & Pink Printed Tunic            4.264145
# 1      Jaipur Kurti Women Blue Printed Maxi Flared S...            4.192575
# 2       20Dresses Women Black & Blue Printed Maxi Dress            4.238206
# 3                      9rasa Black Block Print Palazzos            4.215448
# 4     A.T.U.N All Things Uber Nice Girls Mustard Yel...            4.294393
# ...                                                 ...                 ...
# 7427  studio rasa Women Navy-Blue & Green Flared Max...            4.242957
# 7428  studio rasa Yellow & Off-White Handblock Print...            4.224690
# 7429        trueBrowns Women Navy Blue Solid Maxi Dress            4.305263
# 7430   trueBrowns Women Peach-Coloured Solid Maxi Dress            4.236710
# 7431             trueBrowns Women Pink Solid Maxi Dress            4.314981
#
# [7432 rows x 2 columns]

# %%
# Find all the product index with ratings
tit = ratingCount['title']
# print(tit)
# ind = []
idx = []
for title in tit:

    new_df = myntra[myntra['title'] == title]
    idx.append(new_df.index)
    

prod_idx = []
for i in idx:
    prod_idx.append(i[0])
len(prod_idx)
# Out:
# 7432

# %%
# remove all products withour rarings
myntra = myntra.iloc[prod_idx]
myntra.reset_index(drop = True , inplace = True)
myntra
# Out:
#       index                           uniq_id            crawl_timestamp  \
# 0      6658  c50c56cf3654d8109e642912d546dba4  2019-08-01 03:12:22 +0000
# 1       476  6cfeb7fef97b591d16d14ce62d0ada8b  2019-08-04 03:37:13 +0000
# 2      3804  af473e8c6e890f660950468f118a88a2  2019-06-17 12:26:49 +0000
# 3      7300  b5ecac0e7dfe7b50942835a19d96e291  2019-08-11 06:35:58 +0000
# 4      3312  76c08ce947ef23186ec22198f6a263ba  2019-07-02 19:01:29 +0000
# ...     ...                               ...                        ...
# 7427   4541  db47d4f0ca9c37b56426a3ec208cb942  2019-08-14 06:23:47 +0000
# 7428   3270  694d713920a4955d58b594e9a0542afa  2019-07-15 07:58:11 +0000
# 7429   8421  3fc7f4170def167d09a5576f366fb550  2019-06-10 10:56:16 +0000
# 7430   7323  c55544f9966850fc11da0a05672e0241  2019-06-17 12:25:08 +0000
# 7431   8370  3845665f2a67a4c39dd3a487b274e88e  2019-06-10 11:01:25 +0000
#
#       product_id                                               link     size  \
# 0           6658  https://www.myntra.com/tunics/global-desi/-glo...       XS
# 1            476  https://www.myntra.com/skirts/jaipur-kurti/-ja...       34
# 2           3804  https://www.myntra.com/dresses/20dresses/20dre...        M
# 3           7300  https://www.myntra.com/palazzos/9rasa/9rasa-bl...  Onesize
# 4           3312  https://www.myntra.com/lehenga-choli/atun-all-...     1-2Y
# ...          ...                                                ...      ...
# 7427        4541                     https://www.myntra.com/6552574  Onesize
# 7428        3270  https://www.myntra.com/lehenga-choli/studio-ra...        S
# 7429        8421  https://www.myntra.com/dresses/truebrowns/true...       XL
# 7430        7323  https://www.myntra.com/dresses/truebrowns/true...      5XL
# 7431        8370  https://www.myntra.com/dresses/truebrowns/true...      6XL
#
#           variant_sku                         brand  \
# 0         10247017_XS                   Global Desi
# 1          7626019_34                  Jaipur Kurti
# 2           8714821_M                     20Dresses
# 3     1798310_Onesize                         9rasa
# 4        2508395_1-2Y  A.T.U.N All Things Uber Nice
# ...               ...                           ...
# 7427  6552574_Onesize                   studio rasa
# 7428        8902189_S                   studio rasa
# 7429       7668903_XL                    trueBrowns
# 7430      7668894_5XL                    trueBrowns
# 7431      7668907_6XL                    trueBrowns
#
#                         care_instructions dominant_material  ...  \
# 0                    100 viscose handwash           viscose  ...
# 1                  100 cotton machinewash            cotton  ...
# 2               viscose rayon machinewash     Viscose Rayon  ...
# 3              cotton and viscosehandwash            Cotton  ...
# 4                   100 polyesterdryclean         polyester  ...
# ...                                   ...               ...  ...
# 7427               polysilk dryclean only              Silk  ...
# 7428                  semidupion dryclean            Dupion  ...
# 7429  shell and lining silk blenddryclean              Silk  ...
# 7430                   silk blenddryclean              Silk  ...
# 7431                     blended dryclean                    ...
#
#        is_in_stock                                          inventory  \
# 0     Out of Stock
# 1         In Stock                                                 15
# 2         In Stock  Knit or Woven : Woven | Transparency : Opaque ...
# 3     Out of Stock
# 4     Out of Stock  Dupatta Fabric : Net | Occasion : Festive | Nu...
# ...            ...                                                ...
# 7427      In Stock                                                 10
# 7428  Out of Stock  Occasion : Festive | Number of Components : 2 ...
# 7429      In Stock  Knit or Woven : Woven | Transparency : Opaque ...
# 7430      In Stock  Knit or Woven : Woven | Transparency : Opaque ...
# 7431      In Stock  Knit or Woven : Woven | Transparency : Opaque ...
#
#                                          specifications  \
# 0     Occasion : Ethnic | Main Trend : New Basics | ...
# 1     Knit or Woven : Woven | Transparency : Opaque ...
# 2
# 3     Pattern : Printed | Transparency : Opaque | Bo...
# 4
# ...                                                 ...
# 7427  Knit or Woven : Woven | Transparency : Opaque ...
# 7428
# 7429
# 7430
# 7431
#
#                                           Pre_Inventory  \
# 0
# 1                                                    15
# 2     knit or woven woven transparency opaque shape ...
# 3
# 4     dupatta fabric net occasion festive number of ...
# ...                                                 ...
# 7427                                                 10
# 7428  occasion festive number of components 2 blouse...
# 7429  knit or woven woven transparency opaque shape ...
# 7430  knit or woven woven transparency opaque shape ...
# 7431  knit or woven woven transparency opaque shape ...
#
#                                         preprocess_body  \
# 0     red and pink printed tunic has a round neck th...
# 1     blue woven printed maxi flared skirt has an el...
# 2     black and blue printed woven maxi dress has a ...
# 3     black block print mid rise palazzo trousers ha...
# 4     mustard yellow and maroon lehenga choli with d...
# ...                                                 ...
# 7427  navy blue and green woven flared maxi skirt wi...
# 7428  yellow and off white handblock print lehenga c...
# 7429  navy blue solid woven maxi dress has a v neck ...
# 7430  peach coloured solid woven maxi dress has a v ...
# 7431  pink solid woven maxi dress has a round neck t...
#
#                                              corpusData  \
# 0     XS 100 viscose handwash viscose Pink | Red Red...
# 1     34 100 cotton machinewash cotton Blue Blue Max...
# 2     M viscose rayon machinewash Viscose Rayon Blac...
# 3     Onesize cotton and viscosehandwash Cotton Blac...
# 4     1-2Y 100 polyesterdryclean polyester Yellow | ...
# ...                                                 ...
# 7427  Onesize polysilk dryclean only Silk Green Gree...
# 7428  S semidupion dryclean Dupion Yellow Yellow Rea...
# 7429  XL shell and lining silk blenddryclean Silk Bl...
# 7430  5XL silk blenddryclean Silk   Solid Maxi Dress...
# 7431  6XL blended dryclean  Pink Pink Solid Maxi Dre...
#
#                                                    img1  \
# 0     http://assets.myntassets.com/v1/assets/images/...
# 1     http://assets.myntassets.com/v1/assets/images/...
# 2     http://assets.myntassets.com/v1/assets/images/...
# 3     http://assets.myntassets.com/v1/assets/images/...
# 4     http://assets.myntassets.com/v1/assets/images/...
# ...                                                 ...
# 7427  http://assets.myntassets.com/v1/assets/images/...
# 7428  http://assets.myntassets.com/v1/assets/images/...
# 7429  http://assets.myntassets.com/v1/assets/images/...
# 7430  http://assets.myntassets.com/v1/assets/images/...
# 7431  http://assets.myntassets.com/v1/assets/images/...
#
#                                                    img3  \
# 0     http://assets.myntassets.com/v1/assets/images/...
# 1     http://assets.myntassets.com/v1/assets/images/...
# 2     http://assets.myntassets.com/v1/assets/images/...
# 3     http://assets.myntassets.com/v1/assets/images/...
# 4     http://assets.myntassets.com/v1/assets/images/...
# ...                                                 ...
# 7427  http://assets.myntassets.com/v1/assets/images/...
# 7428  http://assets.myntassets.com/v1/assets/images/...
# 7429  http://assets.myntassets.com/v1/assets/images/...
# 7430  http://assets.myntassets.com/v1/assets/images/...
# 7431  http://assets.myntassets.com/v1/assets/images/...
#
#                                                    img2  \
# 0     http://assets.myntassets.com/v1/assets/images/...
# 1     http://assets.myntassets.com/v1/assets/images/...
# 2     http://assets.myntassets.com/v1/assets/images/...
# 3     http://assets.myntassets.com/v1/assets/images/...
# 4     http://assets.myntassets.com/v1/assets/images/...
# ...                                                 ...
# 7427  http://assets.myntassets.com/v1/assets/images/...
# 7428  http://assets.myntassets.com/v1/assets/images/...
# 7429  http://assets.myntassets.com/v1/assets/images/...
# 7430  http://assets.myntassets.com/v1/assets/images/...
# 7431  http://assets.myntassets.com/v1/assets/images/...
#
#                                                    img4
# 0     http://assets.myntassets.com/v1/assets/images/...
# 1     http://assets.myntassets.com/v1/assets/images/...
# 2     http://assets.myntassets.com/v1/assets/images/...
# 3     http://assets.myntassets.com/v1/assets/images/...
# 4     http://assets.myntassets.com/v1/assets/images/...
# ...                                                 ...
# 7427  http://assets.myntassets.com/v1/assets/images/...
# 7428  http://assets.myntassets.com/v1/assets/images/...
# 7429  http://assets.myntassets.com/v1/assets/images/...
# 7430  http://assets.myntassets.com/v1/assets/images/...
# 7431  http://assets.myntassets.com/v1/assets/images/...
#
# [7432 rows x 33 columns]

# %%
# Remove columns 
drop_columns = ['index' , 'crawl_timestamp' , 'uniq_id' , 'variant_sku', 'link'  , 'care_instructions' , 'is_in_stock', 'images', 'size_fit', 'specifications' ]
new_df = myntra.drop(drop_columns, axis = 1)
new_df.head()
# Out:
#    product_id     size                         brand dominant_material  \
# 0        6658       XS                   Global Desi           viscose
# 1         476       34                  Jaipur Kurti            cotton
# 2        3804        M                     20Dresses     Viscose Rayon
# 3        7300  Onesize                         9rasa            Cotton
# 4        3312     1-2Y  A.T.U.N All Things Uber Nice         polyester
#
#                                                title  \
# 0         Global Desi Women Red & Pink Printed Tunic
# 1   Jaipur Kurti Women Blue Printed Maxi Flared S...
# 2    20Dresses Women Black & Blue Printed Maxi Dress
# 3                   9rasa Black Block Print Palazzos
# 4  A.T.U.N All Things Uber Nice Girls Mustard Yel...
#
#                 actual_color dominant_color                product_type  \
# 0                 Pink | Red            Red                       Tunic
# 1                       Blue           Blue           Maxi Flared Skirt
# 2               Black | Blue          Black                  Maxi Dress
# 3                      Black          Black                    Palazzos
# 4  Yellow | Maroon | Mustard        Mustard  Lehenga Choli with Dupatta
#
#                                                 body  \
# 0  Red and Pink printed Tunic, has a round neck, ...
# 1  Blue woven printed maxi flared skirt, has an e...
# 2  Black and blue printed woven maxi dress, has a...
# 3  Black block print mid-rise palazzo trousers, h...
# 4  Mustard yellow and maroon lehenga choli with d...
#
#                                      product_details  ...  \
# 0  Red and Pink printed Tunic, has a round neck, ...  ...
# 1  Blue woven printed maxi flared skirt, has an e...  ...
# 2  Black and blue printed woven maxi dress, has a...  ...
# 3  Black block print mid-rise palazzo trousers, h...  ...
# 4  Mustard yellow and maroon lehenga choli with d...  ...
#
#   variant_compare_at_price ideal_for  \
# 0                     1799     Women
# 1                     2299     Women
# 2                     1895     Women
# 3                     1299     Women
# 4                     2999     Girls
#
#                                            inventory  \
# 0
# 1                                                 15
# 2  Knit or Woven : Woven | Transparency : Opaque ...
# 3
# 4  Dupatta Fabric : Net | Occasion : Festive | Nu...
#
#                                        Pre_Inventory  \
# 0
# 1                                                 15
# 2  knit or woven woven transparency opaque shape ...
# 3
# 4  dupatta fabric net occasion festive number of ...
#
#                                      preprocess_body  \
# 0  red and pink printed tunic has a round neck th...
# 1  blue woven printed maxi flared skirt has an el...
# 2  black and blue printed woven maxi dress has a ...
# 3  black block print mid rise palazzo trousers ha...
# 4  mustard yellow and maroon lehenga choli with d...
#
#                                           corpusData  \
# 0  XS 100 viscose handwash viscose Pink | Red Red...
# 1  34 100 cotton machinewash cotton Blue Blue Max...
# 2  M viscose rayon machinewash Viscose Rayon Blac...
# 3  Onesize cotton and viscosehandwash Cotton Blac...
# 4  1-2Y 100 polyesterdryclean polyester Yellow | ...
#
#                                                 img1  \
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
# 2  http://assets.myntassets.com/v1/assets/images/...
# 3  http://assets.myntassets.com/v1/assets/images/...
# 4  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img3  \
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
# 2  http://assets.myntassets.com/v1/assets/images/...
# 3  http://assets.myntassets.com/v1/assets/images/...
# 4  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img2  \
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
# 2  http://assets.myntassets.com/v1/assets/images/...
# 3  http://assets.myntassets.com/v1/assets/images/...
# 4  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img4
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
# 2  http://assets.myntassets.com/v1/assets/images/...
# 3  http://assets.myntassets.com/v1/assets/images/...
# 4  http://assets.myntassets.com/v1/assets/images/...
#
# [5 rows x 23 columns]

# %%
drop_from_myntra = ['index' , 'crawl_timestamp', 'uniq_id', 'is_in_stock' , 'link', 'variant_sku', 'care_instructions','images', 'size_fit', 'type', 'is_in_stock' , 'Pre_Inventory', 'preprocess_body', 'corpusData' ]
myntra.drop(drop_from_myntra, axis =1 , inplace = True)

# %%
myntra.shape
# Out:
# (7432, 20)

# %%
# Store updated data into myntra.csv file
myntra.to_csv('myntra.csv')

# %% [markdown]
# ## Popularity based recommendation system

# %%
# merge totalRating and average Rating
rating_df = ratingCount.merge(averageRating , on="title" )
rating_df
# Out:
#                                                   title  TotalCountRating  \
# 0            Global Desi Women Red & Pink Printed Tunic               275
# 1      Jaipur Kurti Women Blue Printed Maxi Flared S...               299
# 2       20Dresses Women Black & Blue Printed Maxi Dress               301
# 3                      9rasa Black Block Print Palazzos               279
# 4     A.T.U.N All Things Uber Nice Girls Mustard Yel...               305
# ...                                                 ...               ...
# 7427  studio rasa Women Navy-Blue & Green Flared Max...               257
# 7428  studio rasa Yellow & Off-White Handblock Print...               290
# 7429        trueBrowns Women Navy Blue Solid Maxi Dress               266
# 7430   trueBrowns Women Peach-Coloured Solid Maxi Dress               310
# 7431             trueBrowns Women Pink Solid Maxi Dress               261
#
#       AverageRatingCount
# 0               4.264145
# 1               4.192575
# 2               4.238206
# 3               4.215448
# 4               4.294393
# ...                  ...
# 7427            4.242957
# 7428            4.224690
# 7429            4.305263
# 7430            4.236710
# 7431            4.314981
#
# [7432 rows x 3 columns]

# %%
rating_df.describe()
# Out:
#        TotalCountRating  AverageRatingCount
# count       7432.000000         7432.000000
# mean         275.910657            4.249761
# std           16.688340            0.026041
# min          212.000000            4.151503
# 25%          265.000000            4.232079
# 50%          276.000000            4.249848
# 75%          287.000000            4.267152
# max          341.000000            4.341514

# %%
# Get popular products by query
polular_df = rating_df[rating_df['TotalCountRating'] > 150].sort_values('AverageRatingCount', ascending=False).head(100)
polular_df
# Out:
#                                                   title  TotalCountRating  \
# 3152     Global Desi Women White Embroidered Bardot Top               284
# 5512  SOJANYA Men Black & Maroon Solid Kurta with Dh...               296
# 1868  Chhabra 555 Women Navy Blue & Golden Made to M...               283
# 3269  House of Pataudi Men Burgundy Woven Design Str...               254
# 950             Anouk Women Pink Printed Straight Kurta               281
# ...                                                 ...               ...
# 2154  Dupatta Bazaar Women Red & Gold-Toned Embroide...               266
# 3771  Inddus Red & Navy Blue & Red Solid Unstitched ...               252
# 3370           I Know Men Red Solid Kurta with Churidar               259
# 4875  Melange by Lifestyle Men Olive Green & Gold-Co...               270
# 6436                           Soch Black Printed Tunic               292
#
#       AverageRatingCount
# 3152            4.341514
# 5512            4.338378
# 1868            4.335548
# 3269            4.334843
# 950             4.333737
# ...                  ...
# 2154            4.307406
# 3771            4.307341
# 3370            4.307336
# 4875            4.307333
# 6436            4.307260
#
# [100 rows x 3 columns]

# %%
# Merge popular products with myntra to get whole data
popular_products = polular_df.merge(myntra , on="title")
popular_products
# Out:
#                                                 title  TotalCountRating  \
# 0      Global Desi Women White Embroidered Bardot Top               284
# 1   SOJANYA Men Black & Maroon Solid Kurta with Dh...               296
# 2   Chhabra 555 Women Navy Blue & Golden Made to M...               283
# 3   House of Pataudi Men Burgundy Woven Design Str...               254
# 4             Anouk Women Pink Printed Straight Kurta               281
# ..                                                ...               ...
# 95  Dupatta Bazaar Women Red & Gold-Toned Embroide...               266
# 96  Inddus Red & Navy Blue & Red Solid Unstitched ...               252
# 97           I Know Men Red Solid Kurta with Churidar               259
# 98  Melange by Lifestyle Men Olive Green & Gold-Co...               270
# 99                           Soch Black Printed Tunic               292
#
#     AverageRatingCount  product_id     size                 brand  \
# 0             4.341514        4788       XS           Global Desi
# 1             4.338378        4694      XXL               SOJANYA
# 2             4.335548        2249    44/42           Chhabra 555
# 3             4.334843        5230        S      House of Pataudi
# 4             4.333737         719      XXL                 Anouk
# ..                 ...         ...      ...                   ...
# 95            4.307406         151  Onesize        Dupatta Bazaar
# 96            4.307341        5639  Onesize                Inddus
# 97            4.307336        5787        L                I Know
# 98            4.307333        1710       XL  Melange by Lifestyle
# 99            4.307260         436        M                  Soch
#
#    dominant_material       actual_color dominant_color  \
# 0             Cotton              White          White
# 1             Cotton     Maroon | Black          Black
# 2               Silk        Blue | Navy           Navy
# 3          Polyester           Burgundy       Burgundy
# 4            viscose               Pink           Pink
# ..               ...                ...            ...
# 95               Net                Red            Red
# 96            Cotton  Red | Blue | Navy            Red
# 97     Viscose Rayon                Red            Red
# 98           viscose      Olive | Green          Olive
# 99            Cotton              Black          Black
#
#               product_type  ...  \
# 0                      Top  ...
# 1   Kurta with Dhoti Pants  ...
# 2            Lehenga Choli  ...
# 3           Straight Kurta  ...
# 4           Straight Kurta  ...
# ..                     ...  ...
# 95                 Dupatta  ...
# 96          Dress Material  ...
# 97     Kurta with Churidar  ...
# 98          Straight Kurta  ...
# 99                   Tunic  ...
#
#                                     complete_the_look variant_price  \
# 0   Expand your collection of cold-weather staples...          2599
# 1   Sport this classic kurta from SOJANYA this sea...          1224
# 2   Grab attention in this elegant made to measure...          5712
# 3   This in-style kurta from House of Pataudi is a...          1979
# 4   This breathable and stylish kurta from Anouk i...          1049
# ..                                                ...           ...
# 95  Enliven your style statement with this appeali...          1199
# 96  This beautifully constructed Inddus dress mate...          1199
# 97  Complete your look with this kurta from I Know...          2399
# 98  From Melange by Lifestyle, this kurta is a gre...           909
# 99  Taking the bright colours of summer and nature...           998
#
#    variant_compare_at_price  ideal_for  \
# 0                      2599      Women
# 1                      3499        Men
# 2                     11900      Women
# 3                      3299        Men
# 4                      1499      Women
# ..                      ...        ...
# 95                     1499      Women
# 96                     3999      Women
# 97                     5999        Men
# 98                     1299        Men
# 99                      998      Women
#
#                                             inventory  \
# 0   Transparency : Opaque | Sleeve Styling : Bell ...
# 1   Sleeve Styling : Regular Sleeves | Occasion : ...
# 2
# 3                                                  14
# 4   Shape : Straight | Sleeve Styling : Regular Sl...
# ..                                                ...
# 95                                                 16
# 96  Dupatta Fabric : Poly Chiffon | Occasion : Dai...
# 97
# 98
# 99  Occasion : Casual | Main Trend : Ethnic Print ...
#
#                                        specifications  \
# 0
# 1
# 2   Dupatta Fabric : Net | Occasion : Festive | Nu...
# 3   Shape : Straight | Sleeve Styling : Regular Sl...
# 4
# ..                                                ...
# 95  Pattern : Embroidered | Occasion : Party | Pri...
# 96
# 97  Occasion : Festive | Number of Components : 2 ...
# 98  Shape : Straight | Sleeve Styling : Regular Sl...
# 99
#
#                                                  img1  \
# 0   http://assets.myntassets.com/v1/assets/images/...
# 1   http://assets.myntassets.com/v1/assets/images/...
# 2   http://assets.myntassets.com/v1/assets/images/...
# 3   http://assets.myntassets.com/v1/assets/images/...
# 4   http://assets.myntassets.com/v1/assets/images/...
# ..                                                ...
# 95  http://assets.myntassets.com/v1/assets/images/...
# 96  http://assets.myntassets.com/v1/assets/images/...
# 97  http://assets.myntassets.com/v1/assets/images/...
# 98  http://assets.myntassets.com/v1/assets/images/...
# 99  http://assets.myntassets.com/v1/assets/images/...
#
#                                                  img3  \
# 0   http://assets.myntassets.com/v1/assets/images/...
# 1   http://assets.myntassets.com/v1/assets/images/...
# 2   http://assets.myntassets.com/v1/assets/images/...
# 3   http://assets.myntassets.com/v1/assets/images/...
# 4   http://assets.myntassets.com/v1/assets/images/...
# ..                                                ...
# 95  http://assets.myntassets.com/v1/assets/images/...
# 96  http://assets.myntassets.com/v1/assets/images/...
# 97  http://assets.myntassets.com/v1/assets/images/...
# 98  http://assets.myntassets.com/v1/assets/images/...
# 99  http://assets.myntassets.com/v1/assets/images/...
#
#                                                  img2  \
# 0   http://assets.myntassets.com/v1/assets/images/...
# 1   http://assets.myntassets.com/v1/assets/images/...
# 2   http://assets.myntassets.com/v1/assets/images/...
# 3   http://assets.myntassets.com/v1/assets/images/...
# 4   http://assets.myntassets.com/v1/assets/images/...
# ..                                                ...
# 95  http://assets.myntassets.com/v1/assets/images/...
# 96  http://assets.myntassets.com/v1/assets/images/...
# 97  http://assets.myntassets.com/v1/assets/images/...
# 98  http://assets.myntassets.com/v1/assets/images/...
# 99  http://assets.myntassets.com/v1/assets/images/...
#
#                                                  img4
# 0   http://assets.myntassets.com/v1/assets/images/...
# 1   http://assets.myntassets.com/v1/assets/images/...
# 2   http://assets.myntassets.com/v1/assets/images/...
# 3   http://assets.myntassets.com/v1/assets/images/...
# 4   http://assets.myntassets.com/v1/assets/images/...
# ..                                                ...
# 95  http://assets.myntassets.com/v1/assets/images/...
# 96  http://assets.myntassets.com/v1/assets/images/...
# 97  http://assets.myntassets.com/v1/assets/images/...
# 98  http://assets.myntassets.com/v1/assets/images/...
# 99  http://assets.myntassets.com/v1/assets/images/...
#
# [100 rows x 22 columns]

# %%
# Function for getting popular products based on gender
def getPopularProd( data, gender, myntra):
    data = data[data['ideal_for'] == gender]
    ratingCount = (data.groupby(by=['title'])['Rating'].count().reset_index().rename(columns = {'Rating': "TotalCountRating"})[["title", "TotalCountRating"]])
    averageRating = (data.groupby(by=['title'])['Rating'].mean().reset_index().rename(columns = {'Rating': "AverageRatingCount"})[["title", "AverageRatingCount"]])
    rating_df = ratingCount.merge(averageRating , on="title" )
    polular_df = rating_df[rating_df['TotalCountRating'] > 100].sort_values('AverageRatingCount', ascending=False).head(100)
    popular_products = polular_df.merge(myntra , on="title")
    return popular_products

# %%
# popular products for women
women_popular = getPopularProd(myntra_merge_ratings , "Women" , myntra)
women_popular
# Out:
#                                                 title  TotalCountRating  \
# 0      Global Desi Women White Embroidered Bardot Top               284
# 1   Chhabra 555 Women Navy Blue & Golden Made to M...               283
# 2             Anouk Women Pink Printed Straight Kurta               281
# 3   Sangria Women Maroon & Beige Printed A-Line Kurta               270
# 4   La Firangi Women Yellow Printed A-Line Layered...               263
# ..                                                ...               ...
# 95  Inddus Women Blue & Golden Dual-Toned Solid Fl...               286
# 96  Rangriti Women Rust Orange Printed Straight Kurta               296
# 97  Inddus Women Peach-Coloured Solid Semi-Stitche...               280
# 98  Clora Creation Women Navy Blue & Gold-Toned Pr...               277
# 99   Libas Women White & Magenta Printed A-Line Kurta               313
#
#     AverageRatingCount  product_id     size           brand dominant_material  \
# 0             4.341514        4788       XS     Global Desi            Cotton
# 1             4.335548        2249    44/42     Chhabra 555              Silk
# 2             4.333737         719      XXL           Anouk           viscose
# 3             4.332259        2859        S         Sangria     Viscose Rayon
# 4             4.332091        2477      XXL      La Firangi     Viscose Rayon
# ..                 ...         ...      ...             ...               ...
# 95            4.302517        8394       28          Inddus              Silk
# 96            4.302466        8533      XXL        Rangriti            cotton
# 97            4.302429        5812  Onesize          Inddus         Poly Silk
# 98            4.302347        1517       28  Clora Creation     Viscose Rayon
# 99            4.302332          31        S           Libas            Cotton
#
#        actual_color dominant_color  \
# 0             White          White
# 1       Blue | Navy           Navy
# 2              Pink           Pink
# 3    Beige | Maroon         Maroon
# 4            Yellow         Yellow
# ..              ...            ...
# 95             Blue           Blue
# 96    Rust | Orange           Rust
# 97
# 98      Blue | Navy           Navy
# 99  White | Magenta          White
#
#                                          product_type  ...  \
# 0                                                 Top  ...
# 1                                       Lehenga Choli  ...
# 2                                      Straight Kurta  ...
# 3                                        A-Line Kurta  ...
# 4                                       Layered Kurta  ...
# ..                                                ...  ...
# 95                                         Maxi Skirt  ...
# 96                                     Straight Kurta  ...
# 97  Semi-Stitched Lehenga & Unstitched Blouse with...  ...
# 98                                         Maxi Skirt  ...
# 99                                       A-Line Kurta  ...
#
#                                     complete_the_look variant_price  \
# 0   Expand your collection of cold-weather staples...          2599
# 1   Grab attention in this elegant made to measure...          5712
# 2   This breathable and stylish kurta from Anouk i...          1049
# 3   Show off your elegant style with a brand new k...           519
# 4   Comfortable and stylish, this kurta from La Fi...           873
# ..                                                ...           ...
# 95  Flaunt a unique boho-chic style with this skir...          1550
# 96  This fashionable kurta from Rangriti will take...           449
# 97  Nothing jazzes up a celebration like a good ol...          2699
# 98  Exhibiting a charming interplay of different h...          1104
# 99  Make a statement with this elegant kurta from ...           999
#
#    variant_compare_at_price  ideal_for  \
# 0                      2599      Women
# 1                     11900      Women
# 2                      1499      Women
# 3                      1299      Women
# 4                      2299      Women
# ..                      ...        ...
# 95                     3299      Women
# 96                      899      Women
# 97                     7499      Women
# 98                     1699      Women
# 99                     1999      Women
#
#                                             inventory  \
# 0   Transparency : Opaque | Sleeve Styling : Bell ...
# 1
# 2   Shape : Straight | Sleeve Styling : Regular Sl...
# 3   Shape : A-Line | Sleeve Styling : Regular Slee...
# 4   Shape : A-Line | Sleeve Styling : Regular Slee...
# ..                                                ...
# 95
# 96
# 97                                                 99
# 98  Knit or Woven : Woven | Transparency : Opaque ...
# 99  Shape : A-Line | Sleeve Styling : Regular Slee...
#
#                                        specifications  \
# 0
# 1   Dupatta Fabric : Net | Occasion : Festive | Nu...
# 2
# 3
# 4
# ..                                                ...
# 95  Knit or Woven : Woven | Transparency : Opaque ...
# 96  Shape : Straight | Sleeve Styling : Regular Sl...
# 97  Dupatta Fabric : Net | Occasion : Festive | Nu...
# 98
# 99
#
#                                                  img1  \
# 0   http://assets.myntassets.com/v1/assets/images/...
# 1   http://assets.myntassets.com/v1/assets/images/...
# 2   http://assets.myntassets.com/v1/assets/images/...
# 3   http://assets.myntassets.com/v1/assets/images/...
# 4   http://assets.myntassets.com/v1/assets/images/...
# ..                                                ...
# 95  http://assets.myntassets.com/v1/assets/images/...
# 96  http://assets.myntassets.com/v1/assets/images/...
# 97  http://assets.myntassets.com/v1/assets/images/...
# 98  http://assets.myntassets.com/v1/assets/images/...
# 99  http://assets.myntassets.com/v1/assets/images/...
#
#                                                  img3  \
# 0   http://assets.myntassets.com/v1/assets/images/...
# 1   http://assets.myntassets.com/v1/assets/images/...
# 2   http://assets.myntassets.com/v1/assets/images/...
# 3   http://assets.myntassets.com/v1/assets/images/...
# 4   http://assets.myntassets.com/v1/assets/images/...
# ..                                                ...
# 95  http://assets.myntassets.com/v1/assets/images/...
# 96  http://assets.myntassets.com/v1/assets/images/...
# 97  http://assets.myntassets.com/v1/assets/images/...
# 98  http://assets.myntassets.com/v1/assets/images/...
# 99  http://assets.myntassets.com/v1/assets/images/...
#
#                                                  img2  \
# 0   http://assets.myntassets.com/v1/assets/images/...
# 1   http://assets.myntassets.com/v1/assets/images/...
# 2   http://assets.myntassets.com/v1/assets/images/...
# 3   http://assets.myntassets.com/v1/assets/images/...
# 4   http://assets.myntassets.com/v1/assets/images/...
# ..                                                ...
# 95  http://assets.myntassets.com/v1/assets/images/...
# 96  http://assets.myntassets.com/v1/assets/images/...
# 97  http://assets.myntassets.com/v1/assets/images/...
# 98  http://assets.myntassets.com/v1/assets/images/...
# 99  http://assets.myntassets.com/v1/assets/images/...
#
#                                                  img4
# 0   http://assets.myntassets.com/v1/assets/images/...
# 1   http://assets.myntassets.com/v1/assets/images/...
# 2   http://assets.myntassets.com/v1/assets/images/...
# 3   http://assets.myntassets.com/v1/assets/images/...
# 4   http://assets.myntassets.com/v1/assets/images/...
# ..                                                ...
# 95  http://assets.myntassets.com/v1/assets/images/...
# 96  http://assets.myntassets.com/v1/assets/images/...
# 97  http://assets.myntassets.com/v1/assets/images/...
# 98  http://assets.myntassets.com/v1/assets/images/...
# 99  http://assets.myntassets.com/v1/assets/images/...
#
# [100 rows x 22 columns]

# %%
# popular products for men
men_popular = getPopularProd(myntra_merge_ratings , "Men" , myntra)
men_popular
# Out:
#                                                 title  TotalCountRating  \
# 0   SOJANYA Men Black & Maroon Solid Kurta with Dh...               296
# 1   House of Pataudi Men Burgundy Woven Design Str...               254
# 2    Freehand Men White & Grey Printed Straight Kurta               267
# 3   I Know Men Navy Blue & White Solid Kurta with ...               277
# 4   British Club Men Peach-Coloured Solid Straight...               287
# ..                                                ...               ...
# 95     Khoday Williams Men Green Solid Straight Kurta               278
# 96  VASTRAMAY Men Black & Grey Checked Straight Kurta               276
# 97  indus route by Pantaloons Men Maroon Woven Des...               273
# 98  British Club Men Maroon Woven Design Straight ...               278
# 99  VASTRAMAY Men Brown & Yellow Printed Straight ...               260
#
#     AverageRatingCount  product_id size                      brand  \
# 0             4.338378        4694  XXL                    SOJANYA
# 1             4.334843        5230    S           House of Pataudi
# 2             4.331386        4904  3XL                   Freehand
# 3             4.330505         411    L                     I Know
# 4             4.328676        5399    S               British Club
# ..                 ...         ...  ...                        ...
# 95            4.295468        1302   XL            Khoday Williams
# 96            4.295362        2405    L                  VASTRAMAY
# 97            4.295165        1934  XXL  indus route by Pantaloons
# 98            4.295000        2285    L               British Club
# 99            4.295000        7369    L                  VASTRAMAY
#
#    dominant_material         actual_color dominant_color  \
# 0             Cotton       Maroon | Black          Black
# 1          Polyester             Burgundy       Burgundy
# 2             cotton         White | Grey          White
# 3      Viscose Rayon  Blue | White | Navy           Navy
# 4             Cotton
# ..               ...                  ...            ...
# 95         Polyester                Green          Green
# 96            Cotton         Black | Grey          Black
# 97            Cotton               Maroon         Maroon
# 98            cotton               Maroon         Maroon
# 99            Cotton       Yellow | Brown          Brown
#
#               product_type  ...  \
# 0   Kurta with Dhoti Pants  ...
# 1           Straight Kurta  ...
# 2           Straight Kurta  ...
# 3       Kurta with Pyjamas  ...
# 4           Straight Kurta  ...
# ..                     ...  ...
# 95          Straight Kurta  ...
# 96          Straight Kurta  ...
# 97          Straight Kurta  ...
# 98          Straight Kurta  ...
# 99          Straight Kurta  ...
#
#                                     complete_the_look variant_price  \
# 0   Sport this classic kurta from SOJANYA this sea...          1224
# 1   This in-style kurta from House of Pataudi is a...          1979
# 2   Flaunt your style with a kurta from Freehand. ...          2099
# 3   Flaunt your style with a kurta from I Know.  W...          1619
# 4   From British Club, this kurta is a great way t...           797
# ..                                                ...           ...
# 95  This in-style kurta from Khoday Williams is a ...           660
# 96  Sport this classic kurta from VASTRAMAY this s...           809
# 97  Flaunt your style with a kurta from indus rout...           599
# 98  From British Club, this kurta is a great way t...           762
# 99  Complete your look with this kurta from VASTRA...          1899
#
#    variant_compare_at_price  ideal_for  \
# 0                      3499        Men
# 1                      3299        Men
# 2                      2099        Men
# 3                      5399        Men
# 4                      1595        Men
# ..                      ...        ...
# 95                     1650        Men
# 96                     2699        Men
# 97                      599        Men
# 98                     1695        Men
# 99                     1899        Men
#
#                                             inventory  \
# 0   Sleeve Styling : Regular Sleeves | Occasion : ...
# 1                                                  14
# 2
# 3   Sleeve Styling : Regular Sleeves | Waistband :...
# 4
# ..                                                ...
# 95
# 96  Shape : Straight | Sleeve Styling : Regular Sl...
# 97  Shape : Straight | Sleeve Styling : Roll-Up Sl...
# 98
# 99
#
#                                        specifications  \
# 0
# 1   Shape : Straight | Sleeve Styling : Regular Sl...
# 2   Shape : Straight | Sleeve Styling : Regular Sl...
# 3
# 4   Shape : Straight | Sleeve Styling : Roll-Up Sl...
# ..                                                ...
# 95  Shape : Straight | Sleeve Styling : Regular Sl...
# 96
# 97
# 98  Shape : Straight | Sleeve Styling : Regular Sl...
# 99  Shape : Straight | Sleeve Styling : Regular Sl...
#
#                                                  img1  \
# 0   http://assets.myntassets.com/v1/assets/images/...
# 1   http://assets.myntassets.com/v1/assets/images/...
# 2   http://assets.myntassets.com/v1/assets/images/...
# 3   http://assets.myntassets.com/v1/assets/images/...
# 4   http://assets.myntassets.com/v1/assets/images/...
# ..                                                ...
# 95  http://assets.myntassets.com/v1/assets/images/...
# 96  http://assets.myntassets.com/v1/assets/images/...
# 97  http://assets.myntassets.com/v1/assets/images/...
# 98  http://assets.myntassets.com/v1/assets/images/...
# 99  http://assets.myntassets.com/v1/assets/images/...
#
#                                                  img3  \
# 0   http://assets.myntassets.com/v1/assets/images/...
# 1   http://assets.myntassets.com/v1/assets/images/...
# 2   http://assets.myntassets.com/v1/assets/images/...
# 3   http://assets.myntassets.com/v1/assets/images/...
# 4   http://assets.myntassets.com/v1/assets/images/...
# ..                                                ...
# 95  http://assets.myntassets.com/v1/assets/images/...
# 96  http://assets.myntassets.com/v1/assets/images/...
# 97  http://assets.myntassets.com/v1/assets/images/...
# 98  http://assets.myntassets.com/v1/assets/images/...
# 99  http://assets.myntassets.com/v1/assets/images/...
#
#                                                  img2  \
# 0   http://assets.myntassets.com/v1/assets/images/...
# 1   http://assets.myntassets.com/v1/assets/images/...
# 2   http://assets.myntassets.com/v1/assets/images/...
# 3   http://assets.myntassets.com/v1/assets/images/...
# 4   http://assets.myntassets.com/v1/assets/images/...
# ..                                                ...
# 95  http://assets.myntassets.com/v1/assets/images/...
# 96  http://assets.myntassets.com/v1/assets/images/...
# 97  http://assets.myntassets.com/v1/assets/images/...
# 98  http://assets.myntassets.com/v1/assets/images/...
# 99  http://assets.myntassets.com/v1/assets/images/...
#
#                                                  img4
# 0   http://assets.myntassets.com/v1/assets/images/...
# 1   http://assets.myntassets.com/v1/assets/images/...
# 2   http://assets.myntassets.com/v1/assets/images/...
# 3   http://assets.myntassets.com/v1/assets/images/...
# 4   http://assets.myntassets.com/v1/assets/images/...
# ..                                                ...
# 95  http://assets.myntassets.com/v1/assets/images/...
# 96  http://assets.myntassets.com/v1/assets/images/...
# 97  http://assets.myntassets.com/v1/assets/images/...
# 98  http://assets.myntassets.com/v1/assets/images/...
# 99  http://assets.myntassets.com/v1/assets/images/...
#
# [100 rows x 22 columns]

# %%
# Dump the files
pickle.dump(women_popular, open('women_popular.pkl', 'wb' ) )
pickle.dump(men_popular, open('men_popular.pkl', 'wb' ) )
pickle.dump(popular_products, open('popular_products.pkl', 'wb' ) )

# %% [markdown]
# ## Collaborative Filtering

# %%
# merge ratings with myntra_merge_ratings
main_data = rating_df.merge(myntra_merge_ratings, on="title")
main_data.head(2)
# Out:
#                                          title  TotalCountRating  \
# 0   Global Desi Women Red & Pink Printed Tunic               275
# 1   Global Desi Women Red & Pink Printed Tunic               275
#
#    AverageRatingCount  userId  product_id  Rating  index  \
# 0            4.264145    5582        6658    4.33   6658
# 1            4.264145    5104        6658    4.71   6658
#
#                             uniq_id            crawl_timestamp  \
# 0  c50c56cf3654d8109e642912d546dba4  2019-08-01 03:12:22 +0000
# 1  c50c56cf3654d8109e642912d546dba4  2019-08-01 03:12:22 +0000
#
#                                                 link  ...   is_in_stock  \
# 0  https://www.myntra.com/tunics/global-desi/-glo...  ...  Out of Stock
# 1  https://www.myntra.com/tunics/global-desi/-glo...  ...  Out of Stock
#
#   inventory                                     specifications Pre_Inventory  \
# 0            Occasion : Ethnic | Main Trend : New Basics | ...
# 1            Occasion : Ethnic | Main Trend : New Basics | ...
#
#                                      preprocess_body  \
# 0  red and pink printed tunic has a round neck th...
# 1  red and pink printed tunic has a round neck th...
#
#                                           corpusData  \
# 0  XS 100 viscose handwash viscose Pink | Red Red...
# 1  XS 100 viscose handwash viscose Pink | Red Red...
#
#                                                 img1  \
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img3  \
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img2  \
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img4
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
#
# [2 rows x 37 columns]

# %%
# Create pivot matrix
pivot_Matrix = main_data.pivot_table(index='title' , columns ='userId' , values='Rating').fillna(0)
pivot_Matrix
# Out:
# userId                                              1     2     3     4     \
# title
#  Global Desi Women Red & Pink Printed Tunic          0.0   0.0   0.0   0.0
#  Jaipur Kurti Women Blue Printed Maxi Flared Skirt   0.0   0.0   0.0   0.0
# 20Dresses Women Black & Blue Printed Maxi Dress      0.0   0.0   0.0   0.0
# 9rasa Black Block Print Palazzos                     0.0   0.0   0.0   0.0
# A.T.U.N All Things Uber Nice Girls Mustard Yell...   0.0   0.0   0.0   0.0
# ...                                                  ...   ...   ...   ...
# studio rasa Women Navy-Blue & Green Flared Maxi...   0.0   0.0   0.0   0.0
# studio rasa Yellow & Off-White Handblock Print ...   0.0   0.0   0.0   0.0
# trueBrowns Women Navy Blue Solid Maxi Dress          0.0   0.0   0.0   0.0
# trueBrowns Women Peach-Coloured Solid Maxi Dress     0.0   0.0   0.0   0.0
# trueBrowns Women Pink Solid Maxi Dress               0.0   0.0   0.0   0.0
#
# userId                                              5     6     7     8     \
# title
#  Global Desi Women Red & Pink Printed Tunic         0.00   0.0   0.0   0.0
#  Jaipur Kurti Women Blue Printed Maxi Flared Skirt  0.00   0.0   0.0   0.0
# 20Dresses Women Black & Blue Printed Maxi Dress     0.00   0.0   0.0   0.0
# 9rasa Black Block Print Palazzos                    0.00   0.0   0.0   0.0
# A.T.U.N All Things Uber Nice Girls Mustard Yell...  4.43   0.0   0.0   0.0
# ...                                                  ...   ...   ...   ...
# studio rasa Women Navy-Blue & Green Flared Maxi...  0.00   0.0   0.0   0.0
# studio rasa Yellow & Off-White Handblock Print ...  0.00   0.0   0.0   0.0
# trueBrowns Women Navy Blue Solid Maxi Dress         0.00   0.0   0.0   0.0
# trueBrowns Women Peach-Coloured Solid Maxi Dress    0.00   0.0   0.0   0.0
# trueBrowns Women Pink Solid Maxi Dress              0.00   0.0   0.0   0.0
#
# userId                                              9     10    ...  7990  \
# title                                                           ...
#  Global Desi Women Red & Pink Printed Tunic          0.0   0.0  ...   0.0
#  Jaipur Kurti Women Blue Printed Maxi Flared Skirt   0.0   0.0  ...   0.0
# 20Dresses Women Black & Blue Printed Maxi Dress      0.0   0.0  ...   0.0
# 9rasa Black Block Print Palazzos                     0.0   0.0  ...   0.0
# A.T.U.N All Things Uber Nice Girls Mustard Yell...   0.0   0.0  ...   0.0
# ...                                                  ...   ...  ...   ...
# studio rasa Women Navy-Blue & Green Flared Maxi...   0.0   0.0  ...   0.0
# studio rasa Yellow & Off-White Handblock Print ...   0.0   0.0  ...   0.0
# trueBrowns Women Navy Blue Solid Maxi Dress          0.0   0.0  ...   0.0
# trueBrowns Women Peach-Coloured Solid Maxi Dress     0.0   0.0  ...   0.0
# trueBrowns Women Pink Solid Maxi Dress               0.0   0.0  ...   0.0
#
# userId                                              7991  7992  7993  7994  \
# title
#  Global Desi Women Red & Pink Printed Tunic          0.0   0.0  0.00   0.0
#  Jaipur Kurti Women Blue Printed Maxi Flared Skirt   0.0   0.0  3.99   0.0
# 20Dresses Women Black & Blue Printed Maxi Dress      0.0   0.0  0.00   0.0
# 9rasa Black Block Print Palazzos                     0.0   0.0  0.00   0.0
# A.T.U.N All Things Uber Nice Girls Mustard Yell...   0.0   0.0  0.00   0.0
# ...                                                  ...   ...   ...   ...
# studio rasa Women Navy-Blue & Green Flared Maxi...   0.0   0.0  0.00   0.0
# studio rasa Yellow & Off-White Handblock Print ...   0.0   0.0  0.00   0.0
# trueBrowns Women Navy Blue Solid Maxi Dress          0.0   0.0  0.00   0.0
# trueBrowns Women Peach-Coloured Solid Maxi Dress     0.0   0.0  0.00   0.0
# trueBrowns Women Pink Solid Maxi Dress               0.0   0.0  0.00   0.0
#
# userId                                              7995  7996  7997  7998  \
# title
#  Global Desi Women Red & Pink Printed Tunic         0.00   0.0   0.0   0.0
#  Jaipur Kurti Women Blue Printed Maxi Flared Skirt  0.00   0.0   0.0   0.0
# 20Dresses Women Black & Blue Printed Maxi Dress     0.00   0.0   0.0   0.0
# 9rasa Black Block Print Palazzos                    0.00   0.0   0.0   0.0
# A.T.U.N All Things Uber Nice Girls Mustard Yell...  0.00   0.0   0.0   0.0
# ...                                                  ...   ...   ...   ...
# studio rasa Women Navy-Blue & Green Flared Maxi...  0.00   0.0   0.0   0.0
# studio rasa Yellow & Off-White Handblock Print ...  3.77   0.0   0.0   0.0
# trueBrowns Women Navy Blue Solid Maxi Dress         0.00   0.0   0.0   0.0
# trueBrowns Women Peach-Coloured Solid Maxi Dress    0.00   0.0   0.0   0.0
# trueBrowns Women Pink Solid Maxi Dress              0.00   0.0   0.0   0.0
#
# userId                                              7999
# title
#  Global Desi Women Red & Pink Printed Tunic          0.0
#  Jaipur Kurti Women Blue Printed Maxi Flared Skirt   0.0
# 20Dresses Women Black & Blue Printed Maxi Dress      0.0
# 9rasa Black Block Print Palazzos                     0.0
# A.T.U.N All Things Uber Nice Girls Mustard Yell...   0.0
# ...                                                  ...
# studio rasa Women Navy-Blue & Green Flared Maxi...   0.0
# studio rasa Yellow & Off-White Handblock Print ...   0.0
# trueBrowns Women Navy Blue Solid Maxi Dress          0.0
# trueBrowns Women Peach-Coloured Solid Maxi Dress     0.0
# trueBrowns Women Pink Solid Maxi Dress               0.0
#
# [7432 rows x 7996 columns]

# %%
# Fit povot_matrix data into Nearest neighbour 
from scipy.sparse import csr_matrix

main_matrix = csr_matrix(pivot_Matrix.values)

from sklearn.neighbors import NearestNeighbors


model_knn = NearestNeighbors(metric = "cosine", algorithm="brute")
model_knn.fit(main_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
# Find distances and indices for every products
distances , indices = model_knn.kneighbors(pivot_Matrix.iloc[0: ].values ,n_neighbors = 7)

# %%
indices
# Out:
# array([[   0, 7394, 3847, ..., 6180, 2710,  560],
#        [   1, 6870, 6824, ..., 4209, 4690, 3030],
#        [   2, 7120, 5656, ..., 4906, 4800,  754],
#        ...,
#        [7429, 2074, 7034, ..., 4080, 3076, 2347],
#        [7430, 1290,  385, ..., 1840,  916, 5672],
#        [7431, 2297, 2382, ...,  456, 6866, 7009]], dtype=int64)

# %%
# Dump pickel files
pickle.dump(pivot_Matrix.index, open('pivot_matrix.pkl', 'wb' ) )
pickle.dump(indices, open('filtered_indices.pkl', 'wb' ) )

# %%
myntra['title'].iloc[4]
# Out:
# 'A.T.U.N All Things Uber Nice Girls Mustard Yellow & Maroon Lehenga Choli with Dupatta'

# %%
dat = np.array(pivot_Matrix.loc[myntra['title'].iloc[4]])
dat = dat.reshape(1 ,-1)

# %%
distances , indices = model_knn.kneighbors(dat ,n_neighbors = 7)

# %% [markdown]
# ## Content Based

# %%
# import ntlk
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
lemmatizer = WordNetLemmatizer()

# Define TfidfVectorizer
tfv = TfidfVectorizer(min_df = 20, stop_words = 'english', analyzer ="word" , strip_accents = "unicode", ngram_range= (1 , 3) )

# Function to lemmatizatio of text
def lemmatizeText(x):
    words = nltk.word_tokenize(x)
    words = [lemmatizer.lemmatize(word) for word in words if word not in set(stopwords.words('english'))]
    x = ' '.join(words)
    return x

# %%
# Apply lemmatization on corpus data
new_df['corpusData'] = new_df['corpusData'].apply(lemmatizeText)
new_df['corpusData']
# Out:
# 0       XS 100 viscose handwash viscose Pink | Red Red...
# 1       34 100 cotton machinewash cotton Blue Blue Max...
# 2       M viscose rayon machinewash Viscose Rayon Blac...
# 3       Onesize cotton viscosehandwash Cotton Black Bl...
# 4       1-2Y 100 polyesterdryclean polyester Yellow | ...
#                               ...
# 7427    Onesize polysilk dryclean Silk Green Green Max...
# 7428    S semidupion dryclean Dupion Yellow Yellow Rea...
# 7429    XL shell lining silk blenddryclean Silk Blue |...
# 7430    5XL silk blenddryclean Silk Solid Maxi Dress p...
# 7431    6XL blended dryclean Pink Pink Solid Maxi Dres...
# Name: corpusData, Length: 7432, dtype: object

# %%
# Fit lemmatized corpus data into tfv
tfv_matrix = tfv.fit_transform(new_df['corpusData'])

# %%
tfv_matrix
# Out:
# <7432x7885 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1286002 stored elements in Compressed Sparse Row format>

# %%
tfv_matrix.shape
# Out:
# (7432, 7885)

# %%
# For getting cosine similarity
from sklearn.metrics.pairwise import sigmoid_kernel

sig = sigmoid_kernel(tfv_matrix , tfv_matrix)

# %%
sig
# Out:
# array([[0.76164741, 0.76159467, 0.76159647, ..., 0.76159489, 0.76159502,
#         0.7615964 ],
#        [0.76159467, 0.76164741, 0.76159784, ..., 0.76159773, 0.7615972 ,
#         0.76159724],
#        [0.76159647, 0.76159784, 0.76164741, ..., 0.76161075, 0.76161245,
#         0.76161472],
#        ...,
#        [0.76159489, 0.76159773, 0.76161075, ..., 0.76164741, 0.76162031,
#         0.76161633],
#        [0.76159502, 0.7615972 , 0.76161245, ..., 0.76162031, 0.76164741,
#         0.76162139],
#        [0.7615964 , 0.76159724, 0.76161472, ..., 0.76161633, 0.76162139,
#         0.76164741]])

# %%
indices = pd.Series(new_df.index , index = new_df['title']).drop_duplicates()
indices
# Out:
# title
#  Global Desi Women Red & Pink Printed Tunic                                                 0
#  Jaipur Kurti Women Blue Printed Maxi Flared Skirt                                          1
# 20Dresses Women Black & Blue Printed Maxi Dress                                             2
# 9rasa Black Block Print Palazzos                                                            3
# A.T.U.N All Things Uber Nice Girls Mustard Yellow & Maroon Lehenga Choli with Dupatta       4
#                                                                                          ...
# studio rasa Women Navy-Blue & Green Flared Maxi Skirt                                    7427
# studio rasa Yellow & Off-White Handblock Print Ready to Wear Lehenga with Blouse         7428
# trueBrowns Women Navy Blue Solid Maxi Dress                                              7429
# trueBrowns Women Peach-Coloured Solid Maxi Dress                                         7430
# trueBrowns Women Pink Solid Maxi Dress                                                   7431
# Length: 7432, dtype: int64

# %%
import pickle
pickle.dump(sig, open('sig.pkl', 'wb' ) )

# %%
pickle.dump(indices, open('indices.pkl', 'wb' ) )

# %%
# Recommandation of similar products based on title
def recommendProduct(title , sig=sig):
    
    index = indices[title]
    
    sig_cs = list(enumerate(sig[index]))
    
    sig = sorted(sig_cs , key = lambda x : x[1] , reverse= True)

    
    sig_cs = sig[1: 11]
    
    product_indices = [i[0] for i in sig_cs]
    
    return myntra.iloc[product_indices]

# %%
new_df['title'][50]
# Out:
# 'AKKRITI BY PANTALOONS Women Red & Blue Printed A-Line Dress'

# %%
recommendProduct("Libas Women Green Yoke Design Straight Kurta")
# Out:
#       product_id size  brand dominant_material  \
# 4322        4892    L  Libas     Viscose Rayon
# 4411        3929    S  Libas     Viscose Rayon
# 4422        5142    S  Libas            Cotton
# 645         1060    M  Anouk     Viscose Rayon
# 4412        5135    M  Libas     Viscose Rayon
# 6128        8531    M  Shree             Rayon
# 4533        3994  XXL  Libas     Viscose Rayon
# 4487          42   XS  Libas     Viscose Rayon
# 604          451  XXL  Anouk           Viscose
# 4413        3281    S  Libas            Cotton
#
#                                                   title          actual_color  \
# 4322  Libas Women Black & Orange Printed Straight Kurta        Black | Orange
# 4411  Libas Women Green & Orange Block Print Straigh...        Green | Orange
# 4422    Libas Women Green Printed Detail Straight Kurta                 Green
# 645              Anouk Women Green Solid Straight Kurta                 Green
# 4412  Libas Women Green & Orange Printed Straight Kurta        Green | Orange
# 6128  Shree Women Green & Orange Printed Straight Kurta        Green | Orange
# 4533  Libas Women Navy Blue & Maroon Solid Straight ...  Maroon | Blue | Navy
# 4487            Libas Women Maroon Solid Straight Kurta                Maroon
# 604    Anouk Women Green & Beige Printed Straight Kurta         Beige | Green
# 4413  Libas Women Green & Pink Floral Print Straight...          Pink | Green
#
#      dominant_color    product_type  \
# 4322          Black  Straight Kurta
# 4411          Green  Straight Kurta
# 4422          Green  Straight Kurta
# 645           Green  Straight Kurta
# 4412          Green  Straight Kurta
# 6128          Green  Straight Kurta
# 4533           Navy  Straight Kurta
# 4487         Maroon  Straight Kurta
# 604           Green  Straight Kurta
# 4413          Green  Straight Kurta
#
#                                                    body  \
# 4322  Black and orange printed straight kurta, has a...
# 4411  Green, orange and golden block print straight ...
# 4422  Green and golden printed detail straight kurta...
# 645   Green solid straight kurta, has a mandarin col...
# 4412  Green and orange printed straight kurta, has a...
# 6128  Green and orange printed straight kurta, has a...
# 4533  Navy Blue solid straight kurta, has a round ne...
# 4487  Maroon solid straight kurta, has a round neck,...
# 604   Green and beige printed straight kurta, has a ...
# 4413  Green and pink floral print straight kurta, ha...
#
#                                         product_details  \
# 4322  Black and orange printed straight kurta, has a...
# 4411  Green, orange and golden block print straight ...
# 4422  Green and golden printed detail straight kurta...
# 645   Green solid straight kurta, has a mandarin col...
# 4412  Green and orange printed straight kurta, has a...
# 6128  Green and orange printed straight kurta, has a...
# 4533  Navy Blue solid straight kurta, has a round ne...
# 4487  Maroon solid straight kurta, has a round neck,...
# 604   Green and beige printed straight kurta, has a ...
# 4413  Green and pink floral print straight kurta, ha...
#
#                                       complete_the_look  variant_price  \
# 4322  You'll love the elegant design and fit of this...            599
# 4411  This fashion-forward kurta from Libas will tak...            719
# 4422  You'll love the elegant design and fit of this...            779
# 645   Show off your elegant style with a brand new k...            519
# 4412  Comfortable and stylish, this kurta from Libas...            584
# 6128  You'll love the elegant design and fit of this...            499
# 4533  You'll love the elegant design and fit of this...            799
# 4487  Make a statement with this elegant kurta from ...            599
# 604   You'll love the elegant design and fit of this...            509
# 4413  This breathable and stylish kurta from Libas i...            649
#
#       variant_compare_at_price ideal_for  \
# 4322                      1499     Women
# 4411                      1799     Women
# 4422                      1299     Women
# 645                       1299     Women
# 4412                      1299     Women
# 6128                       999     Women
# 4533                      1999     Women
# 4487                      1499     Women
# 604                       1699     Women
# 4413                      1299     Women
#
#                                               inventory  \
# 4322
# 4411
# 4422  Shape : Straight | Sleeve Styling : Regular Sl...
# 645
# 4412
# 6128
# 4533
# 4487
# 604
# 4413
#
#                                          specifications  \
# 4322  Shape : Straight | Sleeve Styling : Regular Sl...
# 4411  Shape : Straight | Sleeve Styling : Regular Sl...
# 4422
# 645   Shape : Straight | Sleeve Styling : Regular Sl...
# 4412  Shape : Straight | Sleeve Styling : Regular Sl...
# 6128  Shape : Straight | Sleeve Styling : Regular Sl...
# 4533  Shape : Straight | Sleeve Styling : Regular Sl...
# 4487  Shape : Straight | Sleeve Styling : Flared Sle...
# 604   Shape : Straight | Sleeve Styling : Regular Sl...
# 4413  Shape : Straight | Sleeve Styling : Regular Sl...
#
#                                                    img1  \
# 4322  http://assets.myntassets.com/v1/assets/images/...
# 4411  http://assets.myntassets.com/v1/assets/images/...
# 4422  http://assets.myntassets.com/v1/assets/images/...
# 645   http://assets.myntassets.com/v1/assets/images/...
# 4412  http://assets.myntassets.com/v1/assets/images/...
# 6128  http://assets.myntassets.com/v1/assets/images/...
# 4533  http://assets.myntassets.com/v1/assets/images/...
# 4487  http://assets.myntassets.com/v1/assets/images/...
# 604   http://assets.myntassets.com/v1/assets/images/...
# 4413  http://assets.myntassets.com/v1/assets/images/...
#
#                                                    img3  \
# 4322  http://assets.myntassets.com/v1/assets/images/...
# 4411  http://assets.myntassets.com/v1/assets/images/...
# 4422  http://assets.myntassets.com/v1/assets/images/...
# 645   http://assets.myntassets.com/v1/assets/images/...
# 4412  http://assets.myntassets.com/v1/assets/images/...
# 6128  http://assets.myntassets.com/v1/assets/images/...
# 4533  http://assets.myntassets.com/v1/assets/images/...
# 4487  http://assets.myntassets.com/v1/assets/images/...
# 604   http://assets.myntassets.com/v1/assets/images/...
# 4413  http://assets.myntassets.com/v1/assets/images/...
#
#                                                    img2  \
# 4322  http://assets.myntassets.com/v1/assets/images/...
# 4411  http://assets.myntassets.com/v1/assets/images/...
# 4422  http://assets.myntassets.com/v1/assets/images/...
# 645   http://assets.myntassets.com/v1/assets/images/...
# 4412  http://assets.myntassets.com/v1/assets/images/...
# 6128  http://assets.myntassets.com/v1/assets/images/...
# 4533  http://assets.myntassets.com/v1/assets/images/...
# 4487  http://assets.myntassets.com/v1/assets/images/...
# 604   http://assets.myntassets.com/v1/assets/images/...
# 4413  http://assets.myntassets.com/v1/assets/images/...
#
#                                                    img4
# 4322  http://assets.myntassets.com/v1/assets/images/...
# 4411  http://assets.myntassets.com/v1/assets/images/...
# 4422  http://assets.myntassets.com/v1/assets/images/...
# 645   http://assets.myntassets.com/v1/assets/images/...
# 4412  http://assets.myntassets.com/v1/assets/images/...
# 6128  http://assets.myntassets.com/v1/assets/images/...
# 4533  http://assets.myntassets.com/v1/assets/images/...
# 4487  http://assets.myntassets.com/v1/assets/images/...
# 604   http://assets.myntassets.com/v1/assets/images/...
# 4413  http://assets.myntassets.com/v1/assets/images/...

# %%
# df_men = myntra[myntra['ideal_for'] == "Men"]
# df_men.to_csv("./Dataset/men.csv")
# df_men.shape

# %%
# df_men = myntra[myntra['ideal_for'] == "Women"]
# df_men.to_csv("./Dataset/woman.csv")
# df_men.shape
